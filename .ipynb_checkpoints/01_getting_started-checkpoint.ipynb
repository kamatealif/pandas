# %%
import pandas as pd

# %%
df = pd.read_csv("data/survey_results_public.csv",index_col="ResponseId")
schema_df = pd.read_csv("data/survey_results_schema.csv",index_col="qname")
df.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
# 3           Employed, full-time     Remote  Apples
# 4            Student, full-time        NaN  Apples
# 5            Student, full-time        NaN  Apples
#
#                                                             CodingActivities  \
# ResponseId
# 1                                                                      Hobby
# 2           Hobby;Contribute to open-source projects;Other (please specify):
# 3           Hobby;Contribute to open-source projects;Other (please specify):
# 4                                                                        NaN
# 5                                                                        NaN
#
#                                                                                        EdLevel  \
# ResponseId
# 1                                                                    Primary/elementary school
# 2                                                 Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                              Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4                                       Some college/university study without earning a degree
# 5           Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)
#
#                                                                                                                                                                      LearnCode  \
# ResponseId
# 1                                                                                                                                                       Books / Physical media
# 2                                                   Books / Physical media;Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community)
# 3           Books / Physical media;Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)
# 4                                Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc);Online Courses or Certification
# 5                                                                                                        Other online resources (e.g., videos, blogs, forum, online community)
#
#                                                                                                                  LearnCodeOnline  \
# ResponseId
# 1                                                                                                                            NaN
# 2                                                           Technical documentation;Blogs;Books;Written Tutorials;Stack Overflow
# 3           Technical documentation;Blogs;Books;Written Tutorials;Stack Overflow;Coding sessions (live or recorded);Social Media
# 4                                                                              Stack Overflow;How-to videos;Interactive tutorial
# 5                         Technical documentation;Blogs;Written Tutorials;Stack Overflow;Social Media;Video-based Online Courses
#
#                                                                                                                                                                   TechDoc  \
# ResponseId
# 1                                                                                                                                                                     NaN
# 2           API document(s) and/or SDK document(s);User guides or README files found in the source repository;First-party knowledge base;Traditional public search engine
# 3                                      API document(s) and/or SDK document(s);User guides or README files found in the source repository;Traditional public search engine
# 4                                                                                                                                                                     NaN
# 5           API document(s) and/or SDK document(s);User guides or README files found in the source repository;First-party knowledge base;Traditional public search engine
#
#            YearsCode YearsCodePro                DevType OrgSize  \
# ResponseId
# 1                NaN          NaN                    NaN     NaN
# 2                 20           17  Developer, full-stack     NaN
# 3                 37           27   Developer Experience     NaN
# 4                  4          NaN  Developer, full-stack     NaN
# 5                  9          NaN  Developer, full-stack     NaN
#
#            PurchaseInfluence BuyNewTool BuildvsBuy TechEndorse  \
# ResponseId
# 1                        NaN        NaN        NaN         NaN
# 2                        NaN        NaN        NaN         NaN
# 3                        NaN        NaN        NaN         NaN
# 4                        NaN        NaN        NaN         NaN
# 5                        NaN        NaN        NaN         NaN
#
#                                                          Country Currency  \
# ResponseId
# 1                                       United States of America      NaN
# 2           United Kingdom of Great Britain and Northern Ireland      NaN
# 3           United Kingdom of Great Britain and Northern Ireland      NaN
# 4                                                         Canada      NaN
# 5                                                         Norway      NaN
#
#             CompTotal  \
# ResponseId
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
#
#                                                            LanguageHaveWorkedWith  \
# ResponseId
# 1                                                                             NaN
# 2           Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Python;TypeScript
# 3                                                                              C#
# 4             C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;SQL;TypeScript
# 5                                         C++;HTML/CSS;JavaScript;Lua;Python;Rust
#
#                                                                   LanguageWantToWorkWith  \
# ResponseId
# 1                                                                                    NaN
# 2           Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Kotlin;Python;TypeScript
# 3                                                                                     C#
# 4                              HTML/CSS;Java;JavaScript;PowerShell;Python;SQL;TypeScript
# 5                                                     C++;HTML/CSS;JavaScript;Lua;Python
#
#                                                                   LanguageAdmired  \
# ResponseId
# 1                                                                             NaN
# 2           Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Python;TypeScript
# 3                                                                              C#
# 4                       HTML/CSS;Java;JavaScript;PowerShell;Python;SQL;TypeScript
# 5                                              C++;HTML/CSS;JavaScript;Lua;Python
#
#                      DatabaseHaveWorkedWith      DatabaseWantToWorkWith  \
# ResponseId
# 1                                       NaN                         NaN
# 2               Dynamodb;MongoDB;PostgreSQL                  PostgreSQL
# 3                Firebase Realtime Database  Firebase Realtime Database
# 4           MongoDB;MySQL;PostgreSQL;SQLite    MongoDB;MySQL;PostgreSQL
# 5                         PostgreSQL;SQLite           PostgreSQL;SQLite
#
#                        DatabaseAdmired  \
# ResponseId
# 1                                  NaN
# 2                           PostgreSQL
# 3           Firebase Realtime Database
# 4             MongoDB;MySQL;PostgreSQL
# 5                    PostgreSQL;SQLite
#
#                               PlatformHaveWorkedWith  \
# ResponseId
# 1                                                NaN
# 2           Amazon Web Services (AWS);Heroku;Netlify
# 3                                       Google Cloud
# 4            Amazon Web Services (AWS);Fly.io;Heroku
# 5                                                NaN
#
#                               PlatformWantToWorkWith  \
# ResponseId
# 1                                                NaN
# 2           Amazon Web Services (AWS);Heroku;Netlify
# 3                                       Google Cloud
# 4                   Amazon Web Services (AWS);Vercel
# 5                                                NaN
#
#                                      PlatformAdmired  \
# ResponseId
# 1                                                NaN
# 2           Amazon Web Services (AWS);Heroku;Netlify
# 3                                       Google Cloud
# 4                          Amazon Web Services (AWS)
# 5                                                NaN
#
#                             WebframeHaveWorkedWith  \
# ResponseId
# 1                                              NaN
# 2                    Express;Next.js;Node.js;React
# 3                                     ASP.NET CORE
# 4           jQuery;Next.js;Node.js;React;WordPress
# 5                                              NaN
#
#                       WebframeWantToWorkWith               WebframeAdmired  \
# ResponseId
# 1                                        NaN                           NaN
# 2           Express;Htmx;Node.js;React;Remix         Express;Node.js;React
# 3                               ASP.NET CORE                  ASP.NET CORE
# 4               jQuery;Next.js;Node.js;React  jQuery;Next.js;Node.js;React
# 5                                        NaN                           NaN
#
#              EmbeddedHaveWorkedWith EmbeddedWantToWorkWith    EmbeddedAdmired  \
# ResponseId
# 1                               NaN                    NaN                NaN
# 2                               NaN                    NaN                NaN
# 3                       Rasberry Pi            Rasberry Pi        Rasberry Pi
# 4                       Rasberry Pi                    NaN                NaN
# 5           CMake;Cargo;Rasberry Pi      CMake;Rasberry Pi  CMake;Rasberry Pi
#
#                                      MiscTechHaveWorkedWith  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 4                              NumPy;Pandas;Ruff;TensorFlow
# 5                                                       NaN
#
#                                      MiscTechWantToWorkWith  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 4                                                       NaN
# 5                                                       NaN
#
#                                             MiscTechAdmired  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 4                                                       NaN
# 5                                                       NaN
#
#                                 ToolsTechHaveWorkedWith  \
# ResponseId
# 1                                                   NaN
# 2           Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 3                                               MSBuild
# 4                                        Docker;npm;Pip
# 5                                          APT;Make;npm
#
#                                 ToolsTechWantToWorkWith  \
# ResponseId
# 1                                                   NaN
# 2           Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 3                                               MSBuild
# 4                                 Docker;Kubernetes;npm
# 5                                              APT;Make
#
#                                        ToolsTechAdmired  ... AINextNo change  \
# ResponseId                                               ...
# 1                                                   NaN  ...             NaN
# 2           Docker;Homebrew;Kubernetes;npm;Vite;Webpack  ...             NaN
# 3                                               MSBuild  ...             NaN
# 4                                            Docker;npm  ...             NaN
# 5                                              APT;Make  ...             NaN
#
#            AINextMore integrated AINextLess integrated  \
# ResponseId
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# 5                            NaN                   NaN
#
#            AINextMuch less integrated AIThreat  \
# ResponseId
# 1                                 NaN      NaN
# 2                                 NaN      NaN
# 3                                 NaN      NaN
# 4                                 NaN       No
# 5                                 NaN      NaN
#
#                                                                                                      AIEthics  \
# ResponseId
# 1                                                                                                         NaN
# 2                                                                                                         NaN
# 3                                                                                                         NaN
# 4           Circulating misinformation or disinformation;Missing or incorrect attribution for sources of data
# 5                                                                                                         NaN
#
#                                  AIChallenges TBranch                  ICorPM  \
# ResponseId
# 1                                         NaN      No                     NaN
# 2                                         NaN     Yes  Individual contributor
# 3                                         NaN      No                     NaN
# 4           Don’t trust the output or answers     NaN                     NaN
# 5                                         NaN     NaN                     NaN
#
#            WorkExp Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4  \
# ResponseId
# 1              NaN         NaN         NaN         NaN         NaN
# 2             17.0       Agree    Disagree       Agree       Agree
# 3              NaN         NaN         NaN         NaN         NaN
# 4              NaN         NaN         NaN         NaN         NaN
# 5              NaN         NaN         NaN         NaN         NaN
#
#            Knowledge_5                 Knowledge_6 Knowledge_7 Knowledge_8  \
# ResponseId
# 1                  NaN                         NaN         NaN         NaN
# 2                Agree  Neither agree nor disagree    Disagree       Agree
# 3                  NaN                         NaN         NaN         NaN
# 4                  NaN                         NaN         NaN         NaN
# 5                  NaN                         NaN         NaN         NaN
#
#            Knowledge_9 Frequency_1 Frequency_2 Frequency_3 TimeSearching  \
# ResponseId
# 1                  NaN         NaN         NaN         NaN           NaN
# 2                Agree         NaN         NaN         NaN           NaN
# 3                  NaN         NaN         NaN         NaN           NaN
# 4                  NaN         NaN         NaN         NaN           NaN
# 5                  NaN         NaN         NaN         NaN           NaN
#
#            TimeAnswering Frustration ProfessionalTech ProfessionalCloud  \
# ResponseId
# 1                    NaN         NaN              NaN               NaN
# 2                    NaN         NaN              NaN               NaN
# 3                    NaN         NaN              NaN               NaN
# 4                    NaN         NaN              NaN               NaN
# 5                    NaN         NaN              NaN               NaN
#
#            ProfessionalQuestion Industry JobSatPoints_1 JobSatPoints_4  \
# ResponseId
# 1                           NaN      NaN            NaN            NaN
# 2                           NaN      NaN            0.0            0.0
# 3                           NaN      NaN            NaN            NaN
# 4                           NaN      NaN            NaN            NaN
# 5                           NaN      NaN            NaN            NaN
#
#            JobSatPoints_5 JobSatPoints_6 JobSatPoints_7 JobSatPoints_8  \
# ResponseId
# 1                     NaN            NaN            NaN            NaN
# 2                     0.0            0.0            0.0            0.0
# 3                     NaN            NaN            NaN            NaN
# 4                     NaN            NaN            NaN            NaN
# 5                     NaN            NaN            NaN            NaN
#
#            JobSatPoints_9 JobSatPoints_10 JobSatPoints_11  \
# ResponseId
# 1                     NaN             NaN             NaN
# 2                     0.0             0.0             0.0
# 3                     NaN             NaN             NaN
# 4                     NaN             NaN             NaN
# 5                     NaN             NaN             NaN
#
#                      SurveyLength SurveyEase ConvertedCompYearly JobSat
# ResponseId
# 1                             NaN        NaN                 NaN    NaN
# 2                             NaN        NaN                 NaN    NaN
# 3           Appropriate in length       Easy                 NaN    NaN
# 4                        Too long       Easy                 NaN    NaN
# 5                       Too short       Easy                 NaN    NaN
#
# [5 rows x 113 columns]

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',87)

# %%
# pd.set_option('display.max_colwidth', None)

# %%
df.shape
# Out:
# (65437, 113)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65437 entries, 1 to 65437
# Columns: 113 entries, MainBranch to JobSat
# dtypes: float64(13), object(100)
# memory usage: 56.9+ MB

# %%
schema_df
# Out:
#                          qid  \
# qname
# MainBranch              QID2
# Age                   QID127
# Employment            QID296
# RemoteWork            QID308
# Check                 QID341
# CodingActivities      QID297
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# TechDoc               QID331
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# BuyNewTool            QID279
# BuildvsBuy            QID330
# TechEndorse           QID335
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# Embedded              QID340
# MiscTech              QID265
# ToolsTech             QID275
# NEWCollabTools        QID274
# OpSys                  QID71
# OfficeStackAsync      QID282
# OfficeStackSync       QID307
# AISearchDev           QID327
# NEWSOSites            QID266
# SOVisitFreq           QID100
# SOAccount             QID101
# SOPartFreq            QID102
# SOHow                 QID334
# SOComm                QID106
# AISelect              QID314
# AISent                QID315
# AIBen                 QID324
# AIAcc                 QID316
# AIComplex             QID343
# AITool                QID319
# AINext                QID320
# AIThreat              QID338
# AIEthics              QID339
# AIChallenges          QID346
# TBranch               QID299
# ICorPM                QID287
# WorkExp               QID288
# Knowledge             QID289
# Frequency             QID290
# TimeSearching         QID291
# TimeAnswering         QID292
# Frustration           QID342
# ProfessionalTech      QID304
# ProfessionalCloud     QID332
# ProfessionalQuestion  QID333
# Industry              QID326
# JobSat                QID336
# JobSatPoints          QID337
# SOTeamsUsage          QID286
# SurveyLength          QID132
# SurveyEase            QID133
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# Knowledge_5           QID289
# Knowledge_6           QID289
# Knowledge_7           QID289
# Knowledge_8           QID289
# Knowledge_9           QID289
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# JobSatPoints_1        QID337
# JobSatPoints_4        QID337
# JobSatPoints_5        QID337
# JobSatPoints_6        QID337
# JobSatPoints_7        QID337
# JobSatPoints_8        QID337
# JobSatPoints_9        QID337
# JobSatPoints_10       QID337
# JobSatPoints_11       QID337
#
#                                                                                                                                                                                                                                                                                                                                      question  \
# qname
# MainBranch                                                                                                                                                                                                Which of the following options best describes you today? For the purpose of this survey, a developer is "someone who writes code".*
# Age                                                                                                                                                                                                                                                                                                                        What is your age?*
# Employment                                                                                                                                                                                                                                      Which of the following best describes your current employment status? Select all that apply.*
# RemoteWork                                                                                                                                                                                                                                                                                  Which best describes your current work situation?
# Check                                                                                                                                                                                 Just checking to make sure you are paying attention to the survey questions. Select ‘Apples’ from the list and you can get back to the survey.*<br><br>
# CodingActivities                                                                                                                                                                                                                             Which of the following best describes the code you write outside of work? Select all that apply.
# EdLevel                                                                                                                                                                                                                                  Which of the following best describes the highest level of formal education that you’ve completed? *
# LearnCode                                                                                                                                                                                                                                                                                    How do you learn to code? Select all that apply.
# LearnCodeOnline                                                                                                                                                                                                                                                     What online resources do you use to learn to code? Select all that apply.
# TechDoc                                                                                                                                                                                                                        What is the source of the technical documentation you use most often to learn to code?  Select all that apply.
# YearsCode                                                                                                                                                                                                                                                              Including any education, how many years have you been coding in total?
# YearsCodePro                                                                                                                                                                                                                                  NOT including education, how many years have you coded professionally (as a part of your work)?
# DevType                                                                                                                                                                                                                           Which of the following describes your current job, the one you do most of the time? Please select only one.
# OrgSize                                                                                                                       Approximately how many people are employed by the company or organization you currently work for?  This should only include your primary company, and not the entire holding or parent company if that applies.
# PurchaseInfluence                                                                                                                                                                                                                        What level of influence do you, personally, have over new technology purchases at your organization?
# BuyNewTool                                                                                                                                                                                                                   When buying a new tool or software, how do you discover and research available solutions? Select all that apply.
# BuildvsBuy                                                                                                                                                                          When asked to provide a recommendation for solving a problem at work with a new tool or software, what has been your most recent choice of the following?
# TechEndorse                                                                                                                                                                                                                          What product feature do you care about most when endorsing a technology purchase? Select all that apply.
# Country                                                                                                                                                                                                                                                                        Where do you live? <span style="font-weight: bolder;">*</span>
# Currency                                                                                                                                                                                                    Which currency do you use day-to-day? If your answer is complicated, please pick the one you're most comfortable estimating in. *
# CompTotal             What is your current total <b>annual</b> compensation (salary, bonuses, and perks, before taxes and deductions)? Please enter a whole number in the box below, without any punctuation.  If you are paid hourly, please estimate an equivalent yearly salary. If you prefer not to answer, please leave the box empty.
# Language                                            Which <b>programming, scripting, and markup languages</b> have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)
# Database                                                                   Which <b>database environments </b>have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the database and want to continue to do so, please check both boxes in that row.)
# Platform                                                                         Which <b>cloud platforms</b> have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the platform and want to continue to do so, please check both boxes in that row.)
# Webframe                                                    Which <b>web frameworks and web technologies</b> have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
# Embedded                                                      Which <b>embedded systems and technologies</b> have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
# MiscTech                                                         Which <b>other frameworks and libraries</b> have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
# ToolsTech                 Which <b>developer </b><strong>tools for compiling, building and testing</strong> have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the technology and want to continue to do so, please check both boxes in that row.)
# NEWCollabTools                                                                                                                                                  Which <strong>development environments</strong> did you use regularly over the past year, and which do you want to work with over the next year? Please check all that apply.
# OpSys                                                                                                                                                                                                                                                                         What is the primary <b>operating system</b> in which you work?
# OfficeStackAsync                                                                                                                            Which <b>collaborative work management and/or code documentation tools</b> did you use regularly over the past year, and which do you want to work with over the next year? Select all that apply
# OfficeStackSync                                                                                                                                                                       Which <b>communication tools</b> did you use regularly over the past year, and which do you want to work with over the next year? Select all that apply
# AISearchDev                                                                                                                                                        Which <b>AI-powered search and developer tools</b> did you use regularly over the past year, and which do you want to work with over the next year? Select all that apply.
# NEWSOSites                                                                                                                                                                                                                                             Which of the following Stack Overflow sites have you visited? Select all that apply. *
# SOVisitFreq                                                                                                                                                                                                                                                                            How frequently would you say you visit Stack Overflow?
# SOAccount                                                                                                                                                                                                                                                                                               Do you have a Stack Overflow account?
# SOPartFreq                                                                                                                                                                                  How frequently would you say you participate in Q&amp;A on Stack Overflow? By participate we mean ask, answer, vote for, or comment on questions.
# SOHow                                                                                                                                                                                                                                                                                  How do you use Stack Overflow?  Select all that apply.
# SOComm                                                                                                                                                                                                                                                                     Do you consider yourself a member of the Stack Overflow community?
# AISelect                                                                                                                                                                                                                                                                         Do you currently use AI tools in your development process? *
# AISent                                                                                                                                                                                                                                                   How favorable is your stance on using AI tools as part of your development workflow?
# AIBen                                                                                                                                                                             For the AI tools you use as part of your development workflow, what are the MOST important benefits you are hoping to achieve? Please check all that apply.
# AIAcc                                                                                                                                                                                                                                    How much do you trust the accuracy of the output from AI tools as part of your development workflow?
# AIComplex                                                                                                                                                                                                                                                 How well do the AI tools you use in your development workflow handle complex tasks?
# AITool                                                                                                                                                    Which parts of your development workflow are you currently using AI tools for and which are you interested in using AI tools for over the next year?  Please select all that apply.
# AINext                                                                                                                                                                 Thinking about how your job and process changes over time, how integrated in your workflow do you anticipate AI tools you are currently using will be 1 year from now?
# AIThreat                                                                                                                                                                                                                                                                                   Do you believe AI is a threat to your current job?
# AIEthics                                                                                                                                                                                                                                                 Which AI ethical responsibilities are most important to you?  Select all that apply.
# AIChallenges                                                                                                                                                                                                               What are the challenges to your company/whole team using AI code assistants or GenAI tools? Select all that apply.
# TBranch                                                                                                                                                                                                                            <span style="font-size:16px;">Would you like to participate in the Professional Developer Series? *</span>
# ICorPM                                                                                                                                                                                                                                                                                   Are you an individual contributor or people manager?
# WorkExp                                                                                                                                                                                                                                                                                     How many years of working experience do you have?
# Knowledge                                                                                                                                                                                                                                                                   Please rate your level of agreement with the following statement:
# Frequency                                                                                                                                                                                                                                                                             How frequently do you experience each of the following?
# TimeSearching                                                                                                 On an average day, how much time do you typically spend searching for answers or solutions to problems you encounter at work? (This includes time spent searching on your own, asking a colleague, and waiting for a response).
# TimeAnswering                                                                                                                                                                                                                              On an average day, how much time do you typically spend answering questions you get asked at work?
# Frustration                                                                                                                                                                                                                                         Which of these company challenges causes you the most frustration? Select all that apply.
# ProfessionalTech                                                                                                                                                                                                                                                                                                              My company has:
# ProfessionalCloud                                                                                                                                                                                                                                                         At my company, our applications, databases and services are hosted:
# ProfessionalQuestion                                                                                                                                                                                                                                      When you have a technical question at work, where do you first go to get an answer?
# Industry                                                                                                                                                                                                                                                                                        What industry is the company you work for in?
# JobSat                                                                                                                                                                                                                                                                     How satisfied are you in your current professional developer role?
# JobSatPoints                                                                                                                                                                                  Assign points to the following attributes of your job according to those that contribute the most to your satisfaction out of 100 total points:
# SOTeamsUsage                                                                                                                                                                                                                                                                                     Does your team use Stack Overflow for Teams?
# SurveyLength                                                                                                                                                                                                                                                                        How do you feel about the length of the survey this year?
# SurveyEase                                                                                                                                                                                                                                                                                 How easy or difficult was this survey to complete?
# Knowledge_1                                                                                                                                                                                                                                                                     I have interactions with people outside of my immediate team.
# Knowledge_2                                                                                                                                                                                Knowledge silos prevent me from getting ideas across the organization (i.e., one individual or team has information that isn't shared with others)
# Knowledge_3                                                                                                                                                                                                                                                    I can find up-to-date information within my organization to help me do my job.
# Knowledge_4                                                                                                                                                                                                                                              I am able to quickly find answers to my questions with existing tools and resources.
# Knowledge_5                                                                                                                                                                                                                                       I know which system or resource to use to find information and answers to questions I have.
# Knowledge_6                                                                                                                                                                                                                                                        I often find myself answering questions that I’ve already answered before.
# Knowledge_7                                                                                                                                                                                                                                              Waiting on answers to questions often causes interruptions and disrupts my workflow.
# Knowledge_8                                                                                                                                                                                                    I feel like I have the tools and/or resources to quickly understand and work on any area of my company's code/system/platform.
# Knowledge_9                                                                                                                                                                                                                          I have asked my employer to reimburse me for tools or a product that helps me do my job better or faster
# Frequency_1                                                                                                                                                                                                                                                                          Needing help from people outside of your immediate team?
# Frequency_2                                                                                                                                                                                                                                                                           Interacting with people outside of your immediate team?
# Frequency_3                                                                                                                                                                             Encountering knowledge silos (where one individual or team has information that's not shared or distributed with other individuals or teams) at work?
# JobSatPoints_1                                                                                                                                                                                                                                                                                                   Driving strategy for my team
# JobSatPoints_4                                                                                                                                                                                                                                                                                                    Contributing to open source
# JobSatPoints_5                                                                                                                                                                                                                                                                                                 Securing data and environments
# JobSatPoints_6                                                                                                                                                                                                                                                                           Improving quality of code and developer environments
# JobSatPoints_7                                                                                                                                                                                                                                                     Learning and using new technology, including platforms, APIs and libraries
# JobSatPoints_8                                                                                                                                                                                                                                                    Designing and building environments, databases, and all things architecture
# JobSatPoints_9                                                                                                                                                                                                                 Being a power user of a tool, developer language or process that others come to for answers and guidance about
# JobSatPoints_10                                                                                                                                                                                                                                                                                  Working with new and/or top-quality hardware
# JobSatPoints_11                                                                                                                                                                                             A well-staffed/sourced internal network that makes observability easy so network or runtime issues are addressed and fixed easily
#
#                      force_resp    type selector
# qname
# MainBranch                 True      MC     SAVR
# Age                        True      MC     SAVR
# Employment                 True      MC     MAVR
# RemoteWork                False      MC     SAVR
# Check                      True      MC     SAVR
# CodingActivities          False      MC     MAVR
# EdLevel                    True      MC     SAVR
# LearnCode                 False      MC     MAVR
# LearnCodeOnline           False      MC     MAVR
# TechDoc                   False      MC     MAVR
# YearsCode                 False      MC       DL
# YearsCodePro              False      MC       DL
# DevType                   False      MC     SAVR
# OrgSize                   False      MC     SAVR
# PurchaseInfluence         False      MC     SAVR
# BuyNewTool                False      MC     MAVR
# BuildvsBuy                False      MC     SAVR
# TechEndorse               False      MC     MAVR
# Country                    True      MC       DL
# Currency                   True      MC       DL
# CompTotal                 False      TE       SL
# Language                  False  Matrix   Likert
# Database                  False  Matrix   Likert
# Platform                  False  Matrix   Likert
# Webframe                  False  Matrix   Likert
# Embedded                  False  Matrix   Likert
# MiscTech                  False  Matrix   Likert
# ToolsTech                 False  Matrix   Likert
# NEWCollabTools            False  Matrix   Likert
# OpSys                     False  Matrix   Likert
# OfficeStackAsync          False  Matrix   Likert
# OfficeStackSync           False  Matrix   Likert
# AISearchDev               False  Matrix   Likert
# NEWSOSites                 True      MC     MAVR
# SOVisitFreq               False      MC     SAVR
# SOAccount                 False      MC     SAVR
# SOPartFreq                False      MC     SAVR
# SOHow                     False      MC     MAVR
# SOComm                    False      MC     SAVR
# AISelect                   True      MC     SAVR
# AISent                    False      MC     SAVR
# AIBen                     False      MC     MAVR
# AIAcc                     False      MC     SAVR
# AIComplex                 False      MC     SAVR
# AITool                    False  Matrix   Likert
# AINext                    False  Matrix   Likert
# AIThreat                  False      MC     SAVR
# AIEthics                  False      MC     MAVR
# AIChallenges              False      MC     MAVR
# TBranch                    True      MC     SAVR
# ICorPM                    False      MC     SAVR
# WorkExp                   False  Slider  HSLIDER
# Knowledge                 False  Matrix   Likert
# Frequency                 False  Matrix   Likert
# TimeSearching             False      MC     SAVR
# TimeAnswering             False      MC     SAVR
# Frustration               False      MC     MAVR
# ProfessionalTech          False      MC     MAVR
# ProfessionalCloud         False      MC     SAVR
# ProfessionalQuestion      False      MC     SAVR
# Industry                  False      MC     SAVR
# JobSat                    False      MC      NPS
# JobSatPoints              False      CS     VRTL
# SOTeamsUsage              False      MC     SAVR
# SurveyLength              False      MC     MAVR
# SurveyEase                False      MC     MAVR
# Knowledge_1                 NaN      MC     MAVR
# Knowledge_2                 NaN      MC     MAVR
# Knowledge_3                 NaN      MC     MAVR
# Knowledge_4                 NaN      MC     MAVR
# Knowledge_5                 NaN      MC     MAVR
# Knowledge_6                 NaN      MC     MAVR
# Knowledge_7                 NaN      MC     MAVR
# Knowledge_8                 NaN      MC     MAVR
# Knowledge_9                 NaN      MC     MAVR
# Frequency_1                 NaN      MC     MAVR
# Frequency_2                 NaN      MC     MAVR
# Frequency_3                 NaN      MC     MAVR
# JobSatPoints_1              NaN      MC     MAVR
# JobSatPoints_4              NaN      MC     MAVR
# JobSatPoints_5              NaN      MC     MAVR
# JobSatPoints_6              NaN      MC     MAVR
# JobSatPoints_7              NaN      MC     MAVR
# JobSatPoints_8              NaN      MC     MAVR
# JobSatPoints_9              NaN      MC     MAVR
# JobSatPoints_10             NaN      MC     MAVR
# JobSatPoints_11             NaN      MC     MAVR

# %%
df.shape
# Out:
# (65437, 113)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'TechDoc',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=113)

# %%
df['Employment']
# Out:
# ResponseId
# 1        Employed, full-time
# 2        Employed, full-time
# 3        Employed, full-time
# 4         Student, full-time
# 5         Student, full-time
#                 ...
# 65433    Employed, full-time
# 65434    Employed, full-time
# 65435    Employed, full-time
# 65436    Employed, full-time
# 65437     Student, full-time
# Name: Employment, Length: 65437, dtype: object

# %%
df.loc[[1,2,3],'Employment']
# Out:
# ResponseId
# 1    Employed, full-time
# 2    Employed, full-time
# 3    Employed, full-time
# Name: Employment, dtype: object

# %%
df.loc[1:4,'Employment':'LearnCode']
# Out:
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
# 3           Employed, full-time     Remote  Apples
# 4            Student, full-time        NaN  Apples
#
#                                                             CodingActivities  \
# ResponseId
# 1                                                                      Hobby
# 2           Hobby;Contribute to open-source projects;Other (please specify):
# 3           Hobby;Contribute to open-source projects;Other (please specify):
# 4                                                                        NaN
#
#                                                            EdLevel  \
# ResponseId
# 1                                        Primary/elementary school
# 2                     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4           Some college/university study without earning a degree
#
#                                                                                                                                                                      LearnCode
# ResponseId
# 1                                                                                                                                                       Books / Physical media
# 2                                                   Books / Physical media;Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community)
# 3           Books / Physical media;Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)
# 4                                Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc);Online Courses or Certification

# %%
df.loc[1]
#getting the data of the index 1 no user
# Out:
# MainBranch             I am a developer by profession
# Age                                Under 18 years old
# Employment                        Employed, full-time
# RemoteWork                                     Remote
# Check                                          Apples
#                                     ...
# JobSatPoints_11                                   NaN
# SurveyLength                                      NaN
# SurveyEase                                        NaN
# ConvertedCompYearly                               NaN
# JobSat                                            NaN
# Name: 1, Length: 113, dtype: object

# %%
schema_df.loc['CompTotal','question']
# Out:
# 'What is your current total <b>annual</b> compensation (salary, bonuses, and perks, before taxes and deductions)? Please enter a whole number in the box below, without any punctuation.  If you are paid hourly, please estimate an equivalent yearly salary. If you prefer not to answer, please leave the box empty. '

# %%
# to check weatheer the schemas are alphabeticaly orderred or not
schema_df.sort_index(inplace=True)

# %%
# creating filter to find out the which programming language has the most pstaticmethod
high_salar = (df['CompTotal'] > 70_000)
df[high_salar]
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 73          I am a developer by profession  18-24 years old
# 380         I am a developer by profession  35-44 years old
# 390         I am a developer by profession  25-34 years old
# 393         I am a developer by profession  35-44 years old
# 396         I am a developer by profession  45-54 years old
# ...                                    ...              ...
# 65334       I am a developer by profession  35-44 years old
# 65354       I am a developer by profession  25-34 years old
# 65367       I am a developer by profession  18-24 years old
# 65370       I am a developer by profession  35-44 years old
# 65389       I am a developer by profession  25-34 years old
#
#                                                                                                                  Employment  \
# ResponseId
# 73          Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time
# 380                                                                                                     Employed, full-time
# 390                                                                                  Employed, full-time;Student, part-time
# 393                                                                                                     Employed, full-time
# 396                                                                                                     Employed, full-time
# ...                                                                                                                     ...
# 65334                                                                                                   Employed, full-time
# 65354                                                                                                   Employed, full-time
# 65367                                              Independent contractor, freelancer, or self-employed;Employed, part-time
# 65370                                                                                                   Employed, full-time
# 65389                                              Employed, full-time;Independent contractor, freelancer, or self-employed
#
#                                       RemoteWork   Check  \
# ResponseId
# 73          Hybrid (some remote, some in-person)  Apples
# 380                                       Remote  Apples
# 390                                       Remote  Apples
# 393         Hybrid (some remote, some in-person)  Apples
# 396                                       Remote  Apples
# ...                                          ...     ...
# 65334       Hybrid (some remote, some in-person)  Apples
# 65354       Hybrid (some remote, some in-person)  Apples
# 65367                                     Remote  Apples
# 65370       Hybrid (some remote, some in-person)  Apples
# 65389       Hybrid (some remote, some in-person)  Apples
#
#                                                                                                                      CodingActivities  \
# ResponseId
# 73          Hobby;School or academic work;Professional development or self-paced learning from online courses;Freelance/contract work
# 380                                                                                                    Hobby;Bootstrapping a business
# 390                                                                                                     Hobby;School or academic work
# 393                                                                                          Hobby;Contribute to open-source projects
# 396                                                                                                                             Hobby
# ...                                                                                                                               ...
# 65334                                                                                                                           Hobby
# 65354                                                                                                                           Hobby
# 65367                                                                                                         Freelance/contract work
# 65370                                                                                                                           Hobby
# 65389                               Hobby;Professional development or self-paced learning from online courses;Freelance/contract work
#
#                                                                                        EdLevel  \
# ResponseId
# 73          Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)
# 380                                            Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 390                                     Some college/university study without earning a degree
# 393                                             Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 396                                            Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                                                        ...
# 65334                                          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65354                                          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65367                                             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65370                                             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65389                                             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                                                                                                                                      LearnCode  \
# ResponseId
# 73                                           On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)
# 380                                               Books / Physical media;Other online resources (e.g., videos, blogs, forum, online community);Online Courses or Certification
# 390         Books / Physical media;Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)
# 393                                                                                                                                                     Books / Physical media
# 396                   Books / Physical media;On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)
# ...                                                                                                                                                                        ...
# 65334                                                                             Books / Physical media;Other online resources (e.g., videos, blogs, forum, online community)
# 65354                         Books / Physical media;On the job training;Other online resources (e.g., videos, blogs, forum, online community);Online Courses or Certification
# 65367                                                    Other online resources (e.g., videos, blogs, forum, online community);Online Courses or Certification;Coding Bootcamp
# 65370                                                                             Books / Physical media;Other online resources (e.g., videos, blogs, forum, online community)
# 65389        On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc);Online Courses or Certification
#
#                                                                                                                                                                                                               LearnCodeOnline  \
# ResponseId
# 73                                                                                                          Technical documentation;Blogs;Written Tutorials;Stack Overflow;Social Media;How-to videos;Interactive tutorial;AI
# 380                                                                                                                                                   Technical documentation;Books;Social Media;Written-based Online Courses
# 390                                                                                                                            Written Tutorials;Stack Overflow;Coding sessions (live or recorded);Video-based Online Courses
# 393                                                                                                                                                                                                                       NaN
# 396                                                                                                                                                        Technical documentation;Blogs;Books;Stack Overflow;Social Media;AI
# ...                                                                                                                                                                                                                       ...
# 65334                                                                                                Technical documentation;Blogs;Books;Written Tutorials;Stack Overflow;How-to videos;AI;Auditory material (e.g., podcasts)
# 65354         Technical documentation;Blogs;Books;Written Tutorials;Coding sessions (live or recorded);How-to videos;Video-based Online Courses;Online challenges (e.g., daily or weekly coding challenges);Programming Games
# 65367                                                                                                                                                              Coding sessions (live or recorded);AI;Certification videos
# 65370       Technical documentation;Books;Written Tutorials;Stack Overflow;Coding sessions (live or recorded);How-to videos;Interactive tutorial;Video-based Online Courses;Written-based Online Courses;AI;Programming Games
# 65389                                                                                    Technical documentation;Blogs;Written Tutorials;Stack Overflow;How-to videos;Video-based Online Courses;Written-based Online Courses
#
#                                                                                                                                                                                                                                       TechDoc  \
# ResponseId
# 73          API document(s) and/or SDK document(s);User guides or README files found in the source repository;First-party knowledge base;Traditional public search engine;AI-powered search/dev tool (free);AI-powered search/dev tool (paid)
# 380                                                                                                                                                                                                    API document(s) and/or SDK document(s)
# 390                                                                                                                                                                                                                                       NaN
# 393                                                                                                                                                                                                                                       NaN
# 396                                                                     API document(s) and/or SDK document(s);User guides or README files found in the source repository;AI-powered search/dev tool (free);AI-powered search/dev tool (paid)
# ...                                                                                                                                                                                                                                       ...
# 65334                                                                                                                                                                            First-party knowledge base;AI-powered search/dev tool (paid)
# 65354                                                                                                                                       API document(s) and/or SDK document(s);User guides or README files found in the source repository
# 65367                                                                                                                                                                                                                                     NaN
# 65370                                                                                                                                      API document(s) and/or SDK document(s);First-party knowledge base;Traditional public search engine
# 65389                                                                           API document(s) and/or SDK document(s);User guides or README files found in the source repository;First-party knowledge base;Traditional public search engine
#
#            YearsCode YearsCodePro  \
# ResponseId
# 73                 3            1
# 380               15            6
# 390                7            7
# 393               32           18
# 396               32           25
# ...              ...          ...
# 65334             14            9
# 65354             16           11
# 65367              4            1
# 65370              5            4
# 65389             10            9
#
#                                                   DevType  \
# ResponseId
# 73          Data scientist or machine learning specialist
# 380         Data scientist or machine learning specialist
# 390                                               Student
# 393                                   Engineering manager
# 396                               Other (please specify):
# ...                                                   ...
# 65334                                 Developer, back-end
# 65354                                 Developer, back-end
# 65367                               Developer, full-stack
# 65370                                Developer, front-end
# 65389                             Other (please specify):
#
#                              OrgSize                 PurchaseInfluence  \
# ResponseId
# 73              100 to 499 employees             I have some influence
# 380               20 to 99 employees  I have a great deal of influence
# 390               10 to 19 employees             I have some influence
# 393         1,000 to 4,999 employees     I have little or no influence
# 396               20 to 99 employees  I have a great deal of influence
# ...                              ...                               ...
# 65334       5,000 to 9,999 employees     I have little or no influence
# 65354       10,000 or more employees     I have little or no influence
# 65367               2 to 9 employees  I have a great deal of influence
# 65370           500 to 999 employees     I have little or no influence
# 65389       5,000 to 9,999 employees     I have little or no influence
#
#                                                                                                                                                                                         BuyNewTool  \
# ResponseId
# 73          Start a free trial;Ask developers I know/work with;Ask a generative AI tool;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2 Crowd
# 380                                                                                                                        Ask developers I know/work with;Research companies that have emailed me
# 390                                                                                                                                                                Ask developers I know/work with
# 393                                                                            Start a free trial;Research companies that have advertised on sites I visit;Research companies that have emailed me
# 396                                                           Start a free trial;Ask developers I know/work with;Ask a generative AI tool;Research companies that have advertised on sites I visit
# ...                                                                                                                                                                                            ...
# 65334                                                                                           Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow
# 65354                                                                                                                                                                           Start a free trial
# 65367       Start a free trial;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2 Crowd;Research companies that have advertised on sites I visit
# 65370                                                                                                                                                                                          NaN
# 65389                                                                                Start a free trial;Ask developers I know/work with;Read ratings or reviews on third party sites like G2 Crowd
#
#                                                                              BuildvsBuy  \
# ResponseId
# 73               Is ready-to-go but also customizable for growth and targeted use cases
# 380              Is ready-to-go but also customizable for growth and targeted use cases
# 390         Is set up to be customized and needs to be engineered into a usable product
# 393                    Out-of-the-box is ready to go with little need for customization
# 396              Is ready-to-go but also customizable for growth and targeted use cases
# ...                                                                                 ...
# 65334            Is ready-to-go but also customizable for growth and targeted use cases
# 65354       Is set up to be customized and needs to be engineered into a usable product
# 65367       Is set up to be customized and needs to be engineered into a usable product
# 65370            Is ready-to-go but also customizable for growth and targeted use cases
# 65389                  Out-of-the-box is ready to go with little need for customization
#
#                                                                                                                                                                 TechEndorse  \
# ResponseId
# 73          APIs;Customization;Integrated developer community;Quality support system;AI tool integration;Reputation for quality and excellence;Frequent updates to features
# 380                                                                                                                                APIs;Connected to an open source project
# 390                                                                                                                                                           Customization
# 393                                                                                          APIs;Reputation for quality and excellence;Connected to an open source project
# 396                                                                                   APIs;Customization;Reputation for quality and excellence;Frequent updates to features
# ...                                                                                                                                                                     ...
# 65334                                                                                        APIs;Reputation for quality and excellence;Connected to an open source project
# 65354                                                                                                                                                                   NaN
# 65367                                                                             Quality support system;Reputation for quality and excellence;Frequent updates to features
# 65370                                                                                                                                                                  APIs
# 65389                                                                                                                          Reputation for quality and excellence;Other:
#
#                                                          Country  \
# ResponseId
# 73                                                      Pakistan
# 380                                                       Turkey
# 390                                     United States of America
# 393         United Kingdom of Great Britain and Northern Ireland
# 396         United Kingdom of Great Britain and Northern Ireland
# ...                                                          ...
# 65334                                                     Sweden
# 65354       United Kingdom of Great Britain and Northern Ireland
# 65367                                                   Pakistan
# 65370                                                     Israel
# 65389                                                     Brazil
#
#                              Currency  CompTotal  \
# ResponseId
# 73               PKR\tPakistani rupee  2040000.0
# 380                 EUR European Euro    85000.0
# 390         USD\tUnited States dollar   110000.0
# 393               GBP\tPound sterling   126420.0
# 396               GBP\tPound sterling    95000.0
# ...                               ...        ...
# 65334              SEK\tSwedish krona  1100000.0
# 65354             GBP\tPound sterling   200000.0
# 65367            PKR\tPakistani rupee   300000.0
# 65370         ILS\tIsraeli new shekel   312000.0
# 65389             BRL\tBrazilian real   174000.0
#
#                                                                              LanguageHaveWorkedWith  \
# ResponseId
# 73          Assembly;Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;Python;R;SQL;TypeScript
# 380                                                          JavaScript;Julia;Python;SQL;TypeScript
# 390                                                       HTML/CSS;JavaScript;Python;SQL;TypeScript
# 393                                       C#;HTML/CSS;Java;JavaScript;MicroPython;Python;TypeScript
# 396                                 Bash/Shell (all shells);Go;HTML/CSS;Java;Kotlin;Python;Ruby;SQL
# ...                                                                                             ...
# 65334                                                       Bash/Shell (all shells);Java;Python;SQL
# 65354                                                                       C++;Go;Java;Python;Rust
# 65367                                                                                           NaN
# 65370                                                                                           NaN
# 65389                                                   Bash/Shell (all shells);HTML/CSS;JavaScript
#
#                                          LanguageWantToWorkWith  \
# ResponseId
# 73                                                C#;Rust;Scala
# 380                    Go;JavaScript;Python;Rust;SQL;TypeScript
# 390                                               Go;Rust;Swift
# 393           HTML/CSS;JavaScript;MicroPython;Python;TypeScript
# 396         Bash/Shell (all shells);Go;HTML/CSS;Java;Kotlin;SQL
# ...                                                         ...
# 65334       Bash/Shell (all shells);Java;Kotlin;Python;Rust;SQL
# 65354                                                    Go;Zig
# 65367                                                       NaN
# 65370                                                       NaN
# 65389               Bash/Shell (all shells);HTML/CSS;JavaScript
#
#                                                 LanguageAdmired  \
# ResponseId
# 73                                                          NaN
# 380                            JavaScript;Python;SQL;TypeScript
# 390                                                         NaN
# 393           HTML/CSS;JavaScript;MicroPython;Python;TypeScript
# 396         Bash/Shell (all shells);Go;HTML/CSS;Java;Kotlin;SQL
# ...                                                         ...
# 65334                   Bash/Shell (all shells);Java;Python;SQL
# 65354                                                        Go
# 65367                                                       NaN
# 65370                                                       NaN
# 65389               Bash/Shell (all shells);HTML/CSS;JavaScript
#
#                              DatabaseHaveWorkedWith  \
# ResponseId
# 73                             MongoDB;MySQL;SQLite
# 380                        DuckDB;PostgreSQL;SQLite
# 390                            IBM DB2;MySQL;SQLite
# 393                      BigQuery;Oracle;PostgreSQL
# 396         BigQuery;Elasticsearch;MySQL;PostgreSQL
# ...                                             ...
# 65334             BigQuery;Elasticsearch;PostgreSQL
# 65354                           Dynamodb;PostgreSQL
# 65367                                           NaN
# 65370                                           NaN
# 65389                                           NaN
#
#                                                                 DatabaseWantToWorkWith  \
# ResponseId
# 73          BigQuery;Cassandra;Databricks SQL;Elasticsearch;Neo4J;PostgreSQL;Snowflake
# 380                                                Clickhouse;DuckDB;PostgreSQL;SQLite
# 390                                                Cassandra;MariaDB;MongoDB;Snowflake
# 393                                                          BigQuery;PostgreSQL;Redis
# 396                                                                BigQuery;PostgreSQL
# ...                                                                                ...
# 65334                                                BigQuery;Elasticsearch;PostgreSQL
# 65354                                                       Dynamodb;PostgreSQL;SQLite
# 65367                                                                              NaN
# 65370                                                                              NaN
# 65389                                                                              NaN
#
#                               DatabaseAdmired  \
# ResponseId
# 73                                        NaN
# 380                  DuckDB;PostgreSQL;SQLite
# 390                                       NaN
# 393                       BigQuery;PostgreSQL
# 396                       BigQuery;PostgreSQL
# ...                                       ...
# 65334       BigQuery;Elasticsearch;PostgreSQL
# 65354                     Dynamodb;PostgreSQL
# 65367                                     NaN
# 65370                                     NaN
# 65389                                     NaN
#
#                                                                PlatformHaveWorkedWith  \
# ResponseId
# 73                                                             Microsoft Azure;VMware
# 380         Amazon Web Services (AWS);Cloudflare;Digital Ocean;Hetzner;Netlify;Vercel
# 390                                                         Amazon Web Services (AWS)
# 393                                                         Amazon Web Services (AWS)
# 396                                              Amazon Web Services (AWS);Cloudflare
# ...                                                                               ...
# 65334                                                                    Google Cloud
# 65354                                                       Amazon Web Services (AWS)
# 65367                                                                             NaN
# 65370                                                                             NaN
# 65389                                                             Google Cloud;Vercel
#
#                                                PlatformWantToWorkWith  \
# ResponseId
# 73                  Amazon Web Services (AWS);Databricks;Google Cloud
# 380         Amazon Web Services (AWS);Cloudflare;Google Cloud;Hetzner
# 390                                                               NaN
# 393                                         Amazon Web Services (AWS)
# 396                              Amazon Web Services (AWS);Cloudflare
# ...                                                               ...
# 65334                                                    Google Cloud
# 65354                                       Amazon Web Services (AWS)
# 65367                                                             NaN
# 65370                                                             NaN
# 65389                             Google Cloud;Heroku;Supabase;Vercel
#
#                                          PlatformAdmired  \
# ResponseId
# 73                                                   NaN
# 380         Amazon Web Services (AWS);Cloudflare;Hetzner
# 390                                                  NaN
# 393                            Amazon Web Services (AWS)
# 396                 Amazon Web Services (AWS);Cloudflare
# ...                                                  ...
# 65334                                       Google Cloud
# 65354                          Amazon Web Services (AWS)
# 65367                                                NaN
# 65370                                                NaN
# 65389                                Google Cloud;Vercel
#
#                                             WebframeHaveWorkedWith  \
# ResponseId
# 73          Angular;AngularJS;Express;FastAPI;Flask;jQuery;Node.js
# 380                                           Next.js;React;Vue.js
# 390                                   FastAPI;Flask;Node.js;Vue.js
# 393                                                          React
# 396                                                        Node.js
# ...                                                            ...
# 65334                                                          NaN
# 65354                                                        Flask
# 65367                                                          NaN
# 65370                                                          NaN
# 65389                                Express;Next.js;Node.js;React
#
#                    WebframeWantToWorkWith                WebframeAdmired  \
# ResponseId
# 73                                 Django                            NaN
# 380                         Svelte;Vue.js                         Vue.js
# 390                                   NaN                            NaN
# 393                                 React                          React
# 396                                   NaN                            NaN
# ...                                   ...                            ...
# 65334                                 NaN                            NaN
# 65354                                 NaN                            NaN
# 65367                                 NaN                            NaN
# 65370                                 NaN                            NaN
# 65389       Express;Next.js;Node.js;React  Express;Next.js;Node.js;React
#
#                      EmbeddedHaveWorkedWith EmbeddedWantToWorkWith  \
# ResponseId
# 73                                    CMake                    NaN
# 380                                     NaN                    NaN
# 390                     Arduino;Rasberry Pi                    NaN
# 393                                     NaN                    NaN
# 396                             Rasberry Pi                    NaN
# ...                                     ...                    ...
# 65334                           Rasberry Pi            Rasberry Pi
# 65354       CMake;Cargo;GNU GCC;Rasberry Pi                    NaN
# 65367                                   NaN                    NaN
# 65370                                   NaN                    NaN
# 65389                                   NaN                    NaN
#
#            EmbeddedAdmired  \
# ResponseId
# 73                     NaN
# 380                    NaN
# 390                    NaN
# 393                    NaN
# 396                    NaN
# ...                    ...
# 65334          Rasberry Pi
# 65354                  NaN
# 65367                  NaN
# 65370                  NaN
# 65389                  NaN
#
#                                                                                                                             MiscTechHaveWorkedWith  \
# ResponseId
# 73          Apache Kafka;Apache Spark;CUDA;Hadoop;Hugging Face Transformers;Keras;NumPy;OpenCL;Opencv;Pandas;Scikit-Learn;TensorFlow;Torch/PyTorch
# 380                                                                                               JAX;NumPy;Pandas;Ruff;Scikit-Learn;Torch/PyTorch
# 390                                                                                                                                            NaN
# 393                                                                                                                                            NaN
# 396                                                                                                                                            NaN
# ...                                                                                                                                            ...
# 65334                                                                                                                                          NaN
# 65354                                                                                                            Apache Kafka;Apache Spark;Flutter
# 65367                                                                                                                                          NaN
# 65370                                                                                                                                          NaN
# 65389                                                                                                                                          NaN
#
#                                       MiscTechWantToWorkWith  \
# ResponseId
# 73                      CUDA;mlflow;TensorFlow;Torch/PyTorch
# 380         JAX;NumPy;Pandas;Ruff;Scikit-Learn;Torch/PyTorch
# 390                                                      NaN
# 393                                                      NaN
# 396                                                      NaN
# ...                                                      ...
# 65334                                                    NaN
# 65354                                                    NaN
# 65367                                                    NaN
# 65370                                                    NaN
# 65389                                                    NaN
#
#                                              MiscTechAdmired  \
# ResponseId
# 73                             CUDA;TensorFlow;Torch/PyTorch
# 380         JAX;NumPy;Pandas;Ruff;Scikit-Learn;Torch/PyTorch
# 390                                                      NaN
# 393                                                      NaN
# 396                                                      NaN
# ...                                                      ...
# 65334                                                    NaN
# 65354                                                    NaN
# 65367                                                    NaN
# 65370                                                    NaN
# 65389                                                    NaN
#
#                                                     ToolsTechHaveWorkedWith  \
# ResponseId
# 73                                                      Docker;Homebrew;Pip
# 380                                                       Ansible;Make;Vite
# 390                                           Homebrew;npm;Pip;Vite;Webpack
# 393                                               Gradle;Maven (build tool)
# 396                             Homebrew;Kubernetes;Make;Maven (build tool)
# ...                                                                     ...
# 65334       Docker;Gradle;Homebrew;Kubernetes;Maven (build tool);Pip;Puppet
# 65354                                                           Docker;Make
# 65367                                                                   NaN
# 65370                                                                   NaN
# 65389                                                   Docker;Webpack;Yarn
#
#                                   ToolsTechWantToWorkWith  \
# ResponseId
# 73                                                 Docker
# 380                                                  Vite
# 390                                                   NaN
# 393                             Gradle;Maven (build tool)
# 396           Homebrew;Kubernetes;Make;Maven (build tool)
# ...                                                   ...
# 65334       Docker;Homebrew;Kubernetes;Maven (build tool)
# 65354                                    Docker;Terraform
# 65367                                                 NaN
# 65370                                                 NaN
# 65389                                 Docker;Webpack;Yarn
#
#                                          ToolsTechAdmired  ...  \
# ResponseId                                                 ...
# 73                                                 Docker  ...
# 380                                                  Vite  ...
# 390                                                   NaN  ...
# 393                             Gradle;Maven (build tool)  ...
# 396           Homebrew;Kubernetes;Make;Maven (build tool)  ...
# ...                                                   ...  ...
# 65334       Docker;Homebrew;Kubernetes;Maven (build tool)  ...
# 65354                                              Docker  ...
# 65367                                                 NaN  ...
# 65370                                                 NaN  ...
# 65389                                 Docker;Webpack;Yarn  ...
#
#            AINextNo change                    AINextMore integrated  \
# ResponseId
# 73                     NaN                                      NaN
# 380                    NaN                                      NaN
# 390           Writing code                         Documenting code
# 393           Writing code                                      NaN
# 396                    NaN          Writing code;Search for answers
# ...                    ...                                      ...
# 65334                  NaN                                      NaN
# 65354                  NaN                                      NaN
# 65367                  NaN                                      NaN
# 65370                  NaN  Writing code;Debugging and getting help
# 65389                  NaN                                      NaN
#
#            AINextLess integrated AINextMuch less integrated      AIThreat  \
# ResponseId
# 73                           NaN                        NaN            No
# 380                          NaN                        NaN            No
# 390                          NaN                        NaN            No
# 393                          NaN                        NaN            No
# 396                          NaN                        NaN            No
# ...                          ...                        ...           ...
# 65334                        NaN                        NaN           NaN
# 65354                        NaN                        NaN            No
# 65367                        NaN                        NaN           NaN
# 65370                        NaN                        NaN  I'm not sure
# 65389                        NaN                        NaN  I'm not sure
#
#                                                                                                                                                                                                                                                                          AIEthics  \
# ResponseId
# 73                                                                                                                      Circulating misinformation or disinformation;Missing or incorrect attribution for sources of data;Biased results that do not represent diverse viewpoints
# 380                                                                                                                                                               Circulating misinformation or disinformation;Missing or incorrect attribution for sources of data;Energy demand
# 390                                                                                                                                                                                                                    Circulating misinformation or disinformation;Energy demand
# 393                                                                                                                                                                              Missing or incorrect attribution for sources of data;Imitating a person's likeness;Energy demand
# 396                                                                                                                                                                                                                                                       Other (please specify):
# ...                                                                                                                                                                                                                                                                           ...
# 65334                                                                                                                                                                                                                                                                         NaN
# 65354                                                                                                                                                                Missing or incorrect attribution for sources of data;Biased results that do not represent diverse viewpoints
# 65367                                                                                                                                                                                                                                                                         NaN
# 65370                                                                                                                                                                                                                                                                         NaN
# ...
# ResponseId
# 73          Strongly disagree  Strongly agree  Strongly agree  Strongly agree
# 380            Strongly agree  Strongly agree  Strongly agree  Strongly agree
# 390                  Disagree           Agree  Strongly agree  Strongly agree
# 393                  Disagree           Agree           Agree           Agree
# 396                       NaN             NaN             NaN             NaN
# ...                       ...             ...             ...             ...
# 65334                     NaN             NaN             NaN             NaN
# 65354                     NaN             NaN             NaN             NaN
# 65367                     NaN             NaN             NaN             NaN
# 65370                     NaN             NaN             NaN             NaN
# 65389          Strongly agree           Agree             NaN             NaN
#
#                            Knowledge_6                 Knowledge_7  \
# ResponseId
# 73                      Strongly agree              Strongly agree
# 380                     Strongly agree              Strongly agree
# 390         Neither agree nor disagree  Neither agree nor disagree
# 393         Neither agree nor disagree                       Agree
# 396                                NaN                         NaN
# ...                                ...                         ...
# 65334                              NaN                         NaN
# 65354                              NaN                         NaN
# 65367                              NaN                         NaN
# 65370                              NaN                         NaN
# 65389                              NaN                         NaN
#
#                Knowledge_8        Knowledge_9       Frequency_1  \
# ResponseId
# 73          Strongly agree     Strongly agree  1-2 times a week
# 380         Strongly agree     Strongly agree             Never
# 390         Strongly agree              Agree  3-5 times a week
# 393                  Agree  Strongly disagree  1-2 times a week
# 396                    NaN                NaN               NaN
# ...                    ...                ...               ...
# 65334                  NaN                NaN               NaN
# 65354                  NaN                NaN               NaN
# 65367                  NaN                NaN               NaN
# 65370                  NaN                NaN               NaN
# 65389                  NaN                NaN               NaN
#
#                   Frequency_2       Frequency_3               TimeSearching  \
# ResponseId
# 73          6-10 times a week             Never         30-60 minutes a day
# 380                     Never             Never  Less than 15 minutes a day
# 390          1-2 times a week  1-2 times a week        60-120 minutes a day
# 393         6-10 times a week  1-2 times a week  Less than 15 minutes a day
# 396                       NaN               NaN                         NaN
# ...                       ...               ...                         ...
# 65334                     NaN               NaN                         NaN
# 65354                     NaN               NaN                         NaN
# 65367                     NaN               NaN                         NaN
# 65370                     NaN               NaN                         NaN
# 65389                     NaN               NaN                         NaN
#
#                          TimeAnswering  \
# ResponseId
# 73                60-120 minutes a day
# 380         Less than 15 minutes a day
# 390         Less than 15 minutes a day
# 393                30-60 minutes a day
# 396                                NaN
# ...                                ...
# 65334                              NaN
# 65354                              NaN
# 65367                              NaN
# 65370                              NaN
# 65389                              NaN
#
#                                                                                                                                                                                                                           Frustration  \
# ResponseId
# 73          Amount of technical debt;Number of software tools in use;Complexity of tech stack for deployment;Complexity of tech stack for build;Maintaining security of code being produced;Reliability of tools/systems used in work
# 380                                                                                                                                                                                                Complexity of tech stack for build
# 390                                                                                                                                                                                  Number of software tools in use;Tracking my work
# 393                                                                                                                            Amount of technical debt;Maintaining security of code being produced;Patching/updating core components
# 396                                                                                                                                                                                                                               NaN
# ...                                                                                                                                                                                                                               ...
# 65334                                                                                                                                                                                                                             NaN
# 65354                                                                                                                                                                                                                             NaN
# 65367                                                                                                                                                                                                                             NaN
# 65370                                                                                                                                                                                                                             NaN
# 65389                                                                                                                                                                                                                             NaN
#
#                                                                                                                                                                                                                            ProfessionalTech  \
# ResponseId
# 73          DevOps function;Observability tools;Knowledge sharing community;AI-assisted technology tool(s);Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery
# 380                                                                                                                                                                         Developer portal or other central places to find tools/services
# 390                                                                                                                                                                                                           DevOps function;Microservices
# 393                                                                                                                                                                                                                                     NaN
# 396                                                                                                                                                                                                                                     NaN
# ...                                                                                                                                                                                                                                     ...
# 65334                                                                                                                                                                                                                                   NaN
# 65354                                                                                                                                                                                                                                   NaN
# 65367                                                                                                                                                                                                                                   NaN
# 65370                                                                                                                                                                                                                                   NaN
# 65389                                                                                                                                                                                                                                   NaN
#
#                              ProfessionalCloud  \
# ResponseId
# 73                  Hybrid (on-prem and cloud)
# 380                                    On-prem
# 390         Cloud only (single or multi-cloud)
# 393                 Hybrid (on-prem and cloud)
# 396                                        NaN
# ...                                        ...
# 65334                                      NaN
# 65354                                      NaN
# 65367                                      NaN
# 65370                                      NaN
# 65389                                      NaN
#
#                         ProfessionalQuestion  \
# ResponseId
# 73                  AI-powered search (free)
# 380                 AI-powered search (paid)
# 390                 AI-powered search (free)
# 393         Traditional public search engine
# 396                                      NaN
# ...                                      ...
# 65334                                    NaN
# 65354                                    NaN
# 65367                                    NaN
# 65370                                    NaN
# 65389                                    NaN
#
#                                         Industry JobSatPoints_1  \
# ResponseId
# 73                          Software Development           90.0
# 380         Computer Systems Design and Services            0.0
# 390              Transportation, or Supply Chain           10.0
# 393                 Retail and Consumer Services           40.0
# 396                                          NaN            NaN
# ...                                          ...            ...
# 65334                                        NaN            NaN
# 65354                                        NaN            NaN
# 65367                                        NaN            NaN
# 65370                                        NaN            NaN
# 65389                                        NaN            NaN
#
#            JobSatPoints_4 JobSatPoints_5 JobSatPoints_6 JobSatPoints_7  \
# ResponseId
# 73                   10.0           75.0           65.0          100.0
# 380                   0.0            0.0            0.0            0.0
# 390                   0.0            0.0           20.0           30.0
# 393                   0.0           10.0           30.0            5.0
# 396                   NaN            NaN            NaN            NaN
# ...                   ...            ...            ...            ...
# 65334                 NaN            NaN            NaN            NaN
# 65354                 NaN            NaN            NaN            NaN
# 65367                 NaN            NaN            NaN            NaN
# 65370                 NaN            NaN            NaN            NaN
# 65389                 NaN            NaN            NaN            NaN
#
#            JobSatPoints_8 JobSatPoints_9 JobSatPoints_10 JobSatPoints_11  \
# ResponseId
# 73                  100.0          100.0            50.0            90.0
# 380                   0.0            0.0             0.0             0.0
# 390                   5.0           20.0            10.0             5.0
# 393                  10.0            0.0             0.0             5.0
# 396                   NaN            NaN             NaN             NaN
# ...                   ...            ...             ...             ...
# 65334                 NaN            NaN             NaN             NaN
# 65354                 NaN            NaN             NaN             NaN
# 65367                 NaN            NaN             NaN             NaN
# 65370                 NaN            NaN             NaN             NaN
# 65389                 NaN            NaN             NaN             NaN
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 73                       Too long                        Easy
# 380                      Too long                   Difficult
# 390                      Too long                        Easy
# 393         Appropriate in length  Neither easy nor difficult
# 396         Appropriate in length                        Easy
# ...                           ...                         ...
# 65334                         NaN                         NaN
# 65354                         NaN                         NaN
# 65367                         NaN                         NaN
# 65370                         NaN                         NaN
# 65389                         NaN                         NaN
#
#            ConvertedCompYearly JobSat
# ResponseId
# 73                      7322.0   10.0
# 380                    91295.0   10.0
# 390                   110000.0   10.0
# 393                   161044.0    7.0
# 396                   121018.0    NaN
# ...                        ...    ...
# 65334                      NaN    NaN
# 65354                      NaN    NaN
# 65367                      NaN    NaN
# 65370                      NaN    NaN
# 65389                      NaN    NaN
#
# [22692 rows x 113 columns]

# %%
# lets apply this filter for the some of the column to get more insightfull results
df.loc[high_salar,['Country','Age','LanguageHaveWorkedWith','CompTotal']]
# Out:
#                                                          Country  \
# ResponseId
# 73                                                      Pakistan
# 380                                                       Turkey
# 390                                     United States of America
# 393         United Kingdom of Great Britain and Northern Ireland
# 396         United Kingdom of Great Britain and Northern Ireland
# ...                                                          ...
# 65334                                                     Sweden
# 65354       United Kingdom of Great Britain and Northern Ireland
# 65367                                                   Pakistan
# 65370                                                     Israel
# 65389                                                     Brazil
#
#                         Age  \
# ResponseId
# 73          18-24 years old
# 380         35-44 years old
# 390         25-34 years old
# 393         35-44 years old
# 396         45-54 years old
# ...                     ...
# 65334       35-44 years old
# 65354       25-34 years old
# 65367       18-24 years old
# 65370       35-44 years old
# 65389       25-34 years old
#
#                                                                              LanguageHaveWorkedWith  \
# ResponseId
# 73          Assembly;Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;Python;R;SQL;TypeScript
# 380                                                          JavaScript;Julia;Python;SQL;TypeScript
# 390                                                       HTML/CSS;JavaScript;Python;SQL;TypeScript
# 393                                       C#;HTML/CSS;Java;JavaScript;MicroPython;Python;TypeScript
# 396                                 Bash/Shell (all shells);Go;HTML/CSS;Java;Kotlin;Python;Ruby;SQL
# ...                                                                                             ...
# 65334                                                       Bash/Shell (all shells);Java;Python;SQL
# 65354                                                                       C++;Go;Java;Python;Rust
# 65367                                                                                           NaN
# 65370                                                                                           NaN
# 65389                                                   Bash/Shell (all shells);HTML/CSS;JavaScript
#
#             CompTotal
# ResponseId
# 73          2040000.0
# 380           85000.0
# 390          110000.0
# 393          126420.0
# 396           95000.0
# ...               ...
# 65334       1100000.0
# 65354        200000.0
# 65367        300000.0
# 65370        312000.0
# 65389        174000.0
#
# [22692 rows x 4 columns]

# %%
# now lets check how many people are from the india
people_from_india = (df['Country'] == 'India') & (df['CompTotal'] > 7000)

# %%
df.loc[people_from_india,['Country','Age','LanguageHaveWorkedWith','CompTotal']]
# Out:
#            Country              Age  \
# ResponseId
# 549          India  25-34 years old
# 614          India  18-24 years old
# 666          India  25-34 years old
# 696          India  25-34 years old
# 723          India  18-24 years old
# ...            ...              ...
# 64754        India  18-24 years old
# 64778        India  25-34 years old
# 64812        India  18-24 years old
# 65172        India  25-34 years old
# 65175        India  18-24 years old
#
#                                                                        LanguageHaveWorkedWith  \
# ResponseId
# 549                                            HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 614                              C;C#;C++;HTML/CSS;Java;JavaScript;MicroPython;PHP;Python;SQL
# 666                                                      JavaScript;PHP;Python;SQL;TypeScript
# 696                                                                         Apex;C;Cobol;Ruby
# 723         Bash/Shell (all shells);Dart;Go;HTML/CSS;JavaScript;PHP;PowerShell;SQL;TypeScript
# ...                                                                                       ...
# 64754                                              C;C++;Dart;HTML/CSS;Java;Kotlin;PHP;Python
# 64778                                                             HTML/CSS;JavaScript;PHP;SQL
# 64812                                                                                     NaN
# 65172                                    C#;Go;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 65175                                    Ada;C++;HTML/CSS;Java;TypeScript;Visual Basic (.Net)
#
#             CompTotal
# ResponseId
# 549         1100000.0
# 614          500000.0
# 666         4000000.0
# 696         3600000.0
# 723          800000.0
# ...               ...
# 64754        180000.0
# 64778        600000.0
# 64812        350000.0
# 65172       2500000.0
# 65175         10000.0
#
# [1493 rows x 4 columns]

# %%
# lets check some of the countries with some new tips and tricks
countries = ['India','Canada','United State','United Kingdom']
filt = df['Country'].isin(countries)
df.loc[filt,'Country']
# Out:
# ResponseId
# 4        Canada
# 17       Canada
# 18        India
# 59        India
# 76        India
#           ...
# 65340     India
# 65384     India
# 65414     India
# 65416     India
# 65429     India
# Name: Country, Length: 6335, dtype: object

# %%
# check where the languages worked with contains the python with some string functions

isPython_in = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)
df.loc[isPython_in,'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2                                                             Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Python;TypeScript
# 4                                                               C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;SQL;TypeScript
# 5                                                                                           C++;HTML/CSS;JavaScript;Lua;Python;Rust
# 6                                                     Bash/Shell (all shells);HTML/CSS;Java;JavaScript;Python;Rust;Swift;TypeScript
# 11                                                                                                           JavaScript;Python;Ruby
#                                                                     ...
# 65422                                                                                                Bash/Shell (all shells);Python
# 65428                                                                                                             MATLAB;Python;SQL
# 65432    Bash/Shell (all shells);C;C#;C++;Delphi;Groovy;HTML/CSS;Java;JavaScript;Objective-C;PowerShell;Python;SQL;Swift;TypeScript
# 65436                                                                                      C;C++;Go;Lua;Objective-C;Python;Rust;SQL
# 65437                                                                              C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
# Name: LanguageHaveWorkedWith, Length: 30795, dtype: object

# %%
# just print the isPython_in to see : which is just and series of true or false
isPython_in
# Out:
# ResponseId
# 1        False
# 2         True
# 3        False
# 4         True
# 5         True
#          ...
# 65433    False
# 65434    False
# 65435    False
# 65436     True
# 65437     True
# Name: LanguageHaveWorkedWith, Length: 65437, dtype: bool
